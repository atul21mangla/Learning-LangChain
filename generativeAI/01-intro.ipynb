# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.15

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("groq:llama-3.3-70b-versatile")

# %% [markdown]
# ## Another way

# %%
# from langchain.chat_models import init_chat_model
# model = init_chat_model("llama-3.3-70b-versatile",
# model_provider="groq")

# %% [markdown]
# ## Another way

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="llama-3.3-70b-versatile")

# %%
print(model.invoke("tell a short joke about AI.."))
# Out:
# content='Why did the AI program go to therapy. Because it was struggling to process its emotions.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 42, 'total_tokens': 61, 'completion_time': 0.052286309, 'completion_tokens_details': None, 'prompt_time': 0.00715232, 'prompt_tokens_details': None, 'queue_time': 0.303146409, 'total_time': 0.059438629}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_0761e44d7b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019d5a1e-b5c7-78f1-a1ef-6432ddc75834-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 42, 'output_tokens': 19, 'total_tokens': 61}

# %%
print(llm.invoke("hello bhosdike, i love you"))
# Out:
# content="I appreciate the enthusiasm, but I'm a large language model, I don't have personal relationships or emotions. I'm here to provide information and help with any questions you might have, though. How can I assist you today?" additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 47, 'prompt_tokens': 44, 'total_tokens': 91, 'completion_time': 0.15440146, 'completion_tokens_details': None, 'prompt_time': 0.005414267, 'prompt_tokens_details': None, 'queue_time': 0.049277058, 'total_time': 0.159815727}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019d5a22-356f-7293-b423-fab76c649b7a-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 44, 'output_tokens': 47, 'total_tokens': 91}

# %% [markdown]
# # Streaming and Batch

# %%
for chunk in llm.stream("Write 1000 words paragraph on Cricket."):
    print(chunk.text ,end="",flush=True)
# Out:
# Cricket is a sport that has been a source of entertainment, passion, and excitement for millions of people around the world for over a century. The game has a rich history, with its origins dating back to the 16th century in England, where it was first played by the nobility and upper classes. Over time, the game spread to other parts of the world, including the Indian subcontinent, the Caribbean, and Australia, where it gained immense popularity and became an integral part of the culture. Today, cricket is played in many countries, with international matches and tournaments drawing huge crowds and massive television audiences. The game is played with a bat and ball, with two teams of eleven players each, on a rectangular field with a flat surface, known as a pitch. The objective of the game is simple: to score runs by hitting the ball with the bat and running between two sets of three stumps, known as wickets, while the opposing team tries to stop them by getting the batsmen out. The team with the most runs at the end of the game wins, and the game can be played in various formats, including Test matches, One-Day Internationals (ODIs), and Twenty20 (T20) matches. Test matches are the longest and most traditional form of the game, where teams play for five days, with each team getting two innings to bat and bowl. ODIs, on the other hand, are limited to one day, with each team getting a limited number of overs to bat and bowl. T20 matches are the shortest and most exciting form of the game, where teams play for just three hours, with each team getting a limited number of overs to bat and bowl. The game requires a high level of skill, strategy, and physical fitness, with players needing to have excellent hand-eye coordination, agility, and endurance to perform at their best. The game also has a rich terminology, with terms like "over", "maiden", "century", and "duck" being an integral part of the game. The game has also produced some of the greatest athletes of all time, including Sir Don Bradman, Sachin Tendulkar, and Sir Vivian Richards, who are widely regarded as the greatest batsmen of all time. The game has also had its fair share of controversies, including match-fixing scandals, player disputes, and on-field altercations, which have often marred the game and led to calls for greater regulation and governance. Despite these challenges, the game remains one of the most popular and widely followed sports in the world, with the International Cricket Council (ICC) being the governing body responsible for overseeing the game globally. The ICC has 125 member countries, and the game is played in many countries, including India, Australia, Pakistan, England, and South Africa, which are some of the top cricket-playing nations in the world. The game has also been a source of national pride, with countries often taking great pride in their cricket teams and players. In India, for example, cricket is a national obsession, with the Indian team being one of the most successful and popular teams in the world. The game has also had a significant impact on the economy, with the Indian Premier League (IPL) being one of the most lucrative and popular T20 leagues in the world. The IPL has attracted some of the biggest names in the game, including Virat Kohli, AB de Villiers, and Chris Gayle, and has helped to popularize the game in India and around the world. The game has also been a source of inspiration, with many players using their platform to promote social causes and raise awareness about important issues. In recent years, the game has also seen a significant increase in the number of women players, with the ICC introducing a number of initiatives to promote women's cricket and increase participation in the game. The game has also been affected by technology, with the use of Decision Review System (DRS) and other technologies helping to improve the accuracy and fairness of the game. The game has also been impacted by the rise of social  ...

# %%
responses = model.batch([
    "What is Ai?",
    "what is you name?",
    "what is ML."
])

for r in responses:
    print(r)
# Out:
# content='**Artificial Intelligence (AI)**: AI refers to the development of computer systems that can perform tasks that typically require human intelligence, such as:\n\n1. **Learning**: AI systems can learn from data and improve their performance over time.\n2. **Problem-solving**: AI systems can analyze data, identify patterns, and make decisions or predictions.\n3. **Reasoning**: AI systems can draw inferences, make connections, and understand context.\n4. **Perception**: AI systems can interpret and understand data from sensors, such as images, speech, and text.\n\nThe primary goal of AI is to create systems that can think and act like humans, but with the ability to process and analyze large amounts of data much faster and more accurately.\n\n**Types of AI**:\n\n1. **Narrow or Weak AI**: Designed to perform a specific task, such as image recognition, language translation, or playing chess.\n2. **General or Strong AI**: A hypothetical AI system that possesses human-like intelligence and can perform any intellectual task.\n3. **Superintelligence**: An AI system that is significantly more intelligent than the best human minds.\n\n**AI Applications**:\n\n1. **Virtual Assistants**: Siri, Google Assistant, Alexa\n2. **Image Recognition**: Self-driving cars, facial recognition\n3. **Natural Language Processing**: Language translation, text analysis\n4. **Predictive Maintenance**: Predicting equipment failures, scheduling maintenance\n5. **Healthcare**: Medical diagnosis, personalized medicine\n\n**AI Techniques**:\n\n1. **Machine Learning**: Training AI models on data to make predictions or decisions.\n2. **Deep Learning**: A type of machine learning that uses neural networks to analyze data.\n3. **Rule-Based Systems**: Using predefined rules to make decisions.\n\nAI has the potential to revolutionize many industries and aspects of our lives, but it also raises important questions about ethics, safety, and responsibility.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 383, 'prompt_tokens': 39, 'total_tokens': 422, 'completion_time': 0.772853296, 'completion_tokens_details': None, 'prompt_time': 0.00954864, 'prompt_tokens_details': None, 'queue_time': 0.62022424, 'total_time': 0.782401936}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_43d97c5965', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019d5a2a-569a-7972-ae09-5dc3bfe3348a-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 39, 'output_tokens': 383, 'total_tokens': 422}
# content='I\'m an artificial intelligence model known as Llama. Llama stands for "Large Language Model Meta AI."' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 40, 'total_tokens': 63, 'completion_time': 0.038835233, 'completion_tokens_details': None, 'prompt_time': 0.004199931, 'prompt_tokens_details': None, 'queue_time': 0.62063796, 'total_time': 0.043035164}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_0761e44d7b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019d5a2a-569c-72e3-9e42-1855376cb8a0-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 23, 'total_tokens': 63}
# content="**Machine Learning (ML)** is a subset of artificial intelligence (AI) that involves the use of algorithms and statistical models to enable machines to perform specific tasks without being explicitly programmed. The goal of ML is to allow machines to learn from data, identify patterns, and make decisions or predictions with minimal human intervention.\n\n**Key Characteristics of ML:**\n\n1. **Learning from data**: ML algorithms learn from data, rather than being programmed with explicit rules.\n2. **Pattern recognition**: ML algorithms identify patterns and relationships in data.\n3. **Prediction and decision-making**: ML algorithms use learned patterns to make predictions or decisions.\n4. **Improvement over time**: ML algorithms can improve their performance over time, as they learn from more data.\n\n**Types of ML:**\n\n1. **Supervised Learning**: The algorithm learns from labeled data to predict outcomes.\n2. **Unsupervised Learning**: The algorithm learns from unlabeled data to identify patterns.\n3. **Reinforcement Learning**: The algorithm learns from interactions with an environment to take optimal actions.\n\n**Applications of ML:**\n\n1. **Image and speech recognition**\n2. **Natural language processing**\n3. **Predictive analytics**\n4. **Recommendation systems**\n5. **Autonomous vehicles**\n\n**Real-World Examples of ML:**\n\n1. **Google's image recognition**\n2. **Siri and Alexa's voice assistants**\n3. **Netflix's recommendation algorithm**\n4. **Self-driving cars**\n5. **Medical diagnosis and treatment**" additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 305, 'prompt_tokens': 39, 'total_tokens': 344, 'completion_time': 0.761518949, 'completion_tokens_details': None, 'prompt_time': 0.003697222, 'prompt_tokens_details': None, 'queue_time': 0.613993949, 'total_time': 0.765216171}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_0761e44d7b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019d5a2a-569e-7a53-80b4-c08dbfd26e0c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 39, 'output_tokens': 305, 'total_tokens': 344}
