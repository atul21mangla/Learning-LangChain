# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
model = init_chat_model("groq:qwen/qwen3-32b")

# %%
from langchain.agents import create_agent
from anyio.lowlevel import checkpoint
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model="groq:qwen/qwen3-32b",
    system_prompt="You are a helpful AI Assitant. You only Give direct answer to user not you thinking.",
    checkpointer=InMemorySaver()
)

# %%
### Run with thread id
config={"configurable":{"thread_id":"test1"}}

# %%
from langchain.messages import HumanMessage

response = agent.invoke({"messages":[HumanMessage("Hi, my name is Atul")]},config=config)
print(response)
# Out:
# {'messages': [HumanMessage(content='Hi, my name is Atul', additional_kwargs={}, response_metadata={}, id='ddc2154f-1273-4bf0-ae84-7ee61936bd94'), AIMessage(content='<think>\n\n</think>\n\nHello, Atul! How can I assist you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 39, 'total_tokens': 56, 'completion_time': 0.031431155, 'completion_tokens_details': None, 'prompt_time': 0.002003663, 'prompt_tokens_details': None, 'queue_time': 0.047057197, 'total_time': 0.033434818}, 'model_name': 'qwen/qwen3-32b', 'system_fingerprint': 'fp_5cf921caa2', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d5f18-2d54-7bd3-8766-157e2e287aec-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 17, 'total_tokens': 56})]}

# %%
agent.invoke({"messages":[HumanMessage("What's my name?")]},config)
# Out:
# {'messages': [HumanMessage(content='Hi, my name is Atul', additional_kwargs={}, response_metadata={}, id='ddc2154f-1273-4bf0-ae84-7ee61936bd94'),
#   AIMessage(content='<think>\n\n</think>\n\nHello, Atul! How can I assist you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 39, 'total_tokens': 56, 'completion_time': 0.031431155, 'completion_tokens_details': None, 'prompt_time': 0.002003663, 'prompt_tokens_details': None, 'queue_time': 0.047057197, 'total_time': 0.033434818}, 'model_name': 'qwen/qwen3-32b', 'system_fingerprint': 'fp_5cf921caa2', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d5f18-2d54-7bd3-8766-157e2e287aec-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 17, 'total_tokens': 56}),
# ...
